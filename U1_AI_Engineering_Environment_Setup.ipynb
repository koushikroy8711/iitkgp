# %% [markdown]
# <a href="https://colab.research.google.com/github/koushikroy8711/iitkgp/blob/main/U1_AI_Engineering_Environment_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello AI")

# %%
numbers =[1,2,3,4]
total = sum(numbers)
total

# %%
from transformers import pipeline
generator=pipeline(
    "text-generation",
    model="gpt2"
)
result = generator (
    "AI Engineering is",
    max_length = 30
)
print(result)

# %%
import numpy as np
import time

A = np.random.rand(2000,2000)
B = np.random.rand(2000,2000)

start= time.time()
C=np.matmul(A,B)
end = time.time()
print ("CPU Time: ", end-start)

# %%
import torch
import time

device= "cuda"
A=torch.rand(2000,2000).to(device)
B=torch.rand(2000,2000).to(device)

start=time.time()
C=torch.matmul(A,B)
end=time.time()
print("GPU Time: ", end-start)

# %%
# !python -m venv ai_env

# %%
import torch
x=torch.tensor([1,2,3])
print(x)

# %%
import torch

# 1. Create two basic tensors
tensor_a = torch.tensor([1, 2, 3])
tensor_b = torch.tensor([4, 5, 6])

# 2. Add them together
result = tensor_a + tensor_b

print(result)

# %%
# 1. Create a tensor representing the number 2.0.
# Setting 'requires_grad=True' is the key here—it tells PyTorch's
# engine to track every mathematical operation done to 'x' so it
# can calculate the gradient (derivative) later.
x = torch.tensor(2.0, requires_grad=True)

# 2. Define the equation.
# Here, y is equal to x squared.
y = x**2

# 3. Trigger the automatic differentiation.
# Calling backward() computes the derivative of 'y' with respect to 'x'.
# Mathematically, the derivative of x^2 is 2x.
y.backward()

# 4. Print the result.
# PyTorch stores the computed derivative inside the '.grad' attribute of x.
# Since x = 2.0, the calculation is 2 * (2.0) = 4.0.
print(x.grad)

# %%
pip install transformers torch
# transformers loads the LLM Model
# torch loads the Deep Learning model

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model = "gpt2"
)

# This code downloads the GPT2 model and loads the tokenizer.

# %%
prompt = "Artificial Intelligence will transform healthcare by"

# %%
result=generator(
    prompt,
    max_length=50,
    num_return_sequences=1
)
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(result[0]["generated_text"])
# Out:
# Artificial Intelligence will transform healthcare by providing the greatest amount of care.
#
# As a result of this, AI will enable healthcare, the healthcare industry, the healthcare industry's future, and the healthcare industry's future.
#
# I have heard the buzz about artificial intelligence, so let me share with you, what it's going to offer. How will it help, and what will it cost?
#
# The big idea is to create a database of medical records that can be used to give healthcare providers a handle on patients' healthcare needs.
#
# The database will serve as a database of medical records that can be used to tell healthcare providers what will be most helpful to them.
#
# The database will provide healthcare providers the information they need to determine what they need in their healthcare care.
#
# The database will enable healthcare providers to deliver healthcare without the use of human labor, or the use of human labor.
#
# This is a big deal.
#
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
print(torch.version.cuda)
# Out:
# 12.8

# %%
print(torch.cuda.get_device_name(0))
# Out:
# Tesla T4
